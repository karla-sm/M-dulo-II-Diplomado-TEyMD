# %% [markdown]
# <a href="https://colab.research.google.com/github/karla-sm/M-dulo-II-Diplomado-TEyMD/blob/main/Trabajo_3_Equipo_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <h1><center> **Facultad de Estudios Superiores Acatlán.** </center></h1>
# # <h3><center> **Metodos Estadisticos y Mineria de Datos** </center></h3>
# # <h4><center> **Modulo II** </center></h4>
#
# ---
#
# # <center> *Ejercicios de Probabilidad* </center>
#
# ---
#
# **Integrantes del Equipo 5:**
#
#   *   *Omar Misael Valero Silva*
#   *   *Karla Anahí Sánchez Morales*
#   *   *Karol Jacqueline Nolasco Reyes*
#   *   *David Mendieta Lopez*
#   *   *César Gabriel López López*

# %% [markdown]
# $\color{red}{\text{Ejercicio 1.}}$ Un alumno se dirige a la biblioteca para solicitar el préstamo de un libro y decide que no puede esperar más de $10$ minutos en ser atendido. Supongamos que el bibliotecario tarda por lo menos $0.5$ minutos en atender a una persona, entonces es razonable proponer una distribución uniforme en el intervalo $[0.5,10]$ para modelar el comportamiento de la variable $X$ que es el tiempo en ser atendido (en  minutos).
#
# - Da la función de densidad y gráfica.
# - ¿Cuál es la probabilidad de que el tiempo en ser atendido sea mayor a $5$ minutos pero menor a $8$ minutos?
# - ¿Cuál es la esperanza y varianza?
# - Calcula la función de distribución y con ella calcula: $\mathbb{P}(2.51\le X \le 7.99)$.

# %% [markdown]
# **Solución:**
# - Da la función de densidad y gráfica.\
# Sea $X\sim Unif((0.5,10))$.
# La función de densidad de esta variable aleatoria esta dada por:
# $$f_{X}(x)=\begin{cases}
# 	\quad \frac{19}{2} &\quad \text{si } 0.5\le x \le 10\\
# 	\quad 0 &\quad \text{e.o.c}
# \end{cases}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Paramétros de la distribución uniforme
a = 0.5 # límite inferior
b = 10 # límite superior

# Crear el objeto de distribución uniforme usando scipy
uniform_dist = uniform(loc = a, scale = b - a)

# Generar valores de x
x = np.linspace(0, 11, 1000)

# Calcular la PDF usando scipy
pdf_values = uniform_dist.pdf(x)

# Calcular la CDF usando scipy
cdf_values = uniform_dist.cdf(x)

# Graficar PDF y CDF
fig, ax = plt.subplots(2, 1, figsize=(8, 6))

# Grafica PDF
ax[0].plot(x, pdf_values, label='PDF', color="blue")
ax[0].set_title("Función de Densidad y Probabilidad (PDF)")
ax[0].set_xlabel("x")
ax[0].set_ylabel("f(x)")
ax[0].grid()
ax[0].legend()

# Grafica CDF
ax[1].plot(x, cdf_values, label='CDF', color="red")
ax[1].set_title("Función de Distribución Acumulada (CDF)")
ax[1].set_xlabel("x")
ax[1].set_ylabel("F(x)")
ax[1].grid()
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ¿Cuál es la probabilidad de que el tiempo en ser atendido sea mayor a $5$ minutos pero menor a $8$ minutos?

# %%
from scipy.stats import uniform
a = 0.5
b = 10
distribucion_uniforme = uniform(loc=a, scale=b-a)
probabilidad_5_a_8 = distribucion_uniforme.cdf(8) - distribucion_uniforme.cdf(5)
print(f"La probabilidad de que el tiempo esté entre 5 y 8 minutos es: {probabilidad_5_a_8}")
# Out:
# La probabilidad de que el tiempo esté entre 5 y 8 minutos es: 0.31578947368421056

# %% [markdown]
# ¿Cuál es la esperanza y varianza?

# %%
a= 0.5
b=10
esperanza = (a + b) / 2
varianza = (b - a)**2 / 12
print(f"La esperanza es: {esperanza}")
print(f"La varianza es: {varianza}")
# Out:
# La esperanza es: 5.25
# La varianza es: 7.520833333333333

# %% [markdown]
# Calcula la función de distribución y con ella calcula: $\mathbb{P}(2.51\le X \le 7.99)$.

# %% [markdown]
# La función de distribución de $X\sim Unif((0.5,10))$ esta dada por:
# $$F_{X}(x)=\begin{cases}
#    0 &\quad \text{si } x\le 0.5 \\
#   \frac{x-0.5}{10-0.5} &\quad \text{si } 0.5<x<10\\
#    1 &\quad \text{si } x\ge 10
# \end{cases}$$

# %%
def cdf_uniform(x, a, b):
    if x < a:
        return 0
    elif a <= x <= b:
        return (x - a) / (b - a)
    else:
        return 1
probabilidad_2_51_a_7_99 = cdf_uniform(7.99, a, b) - cdf_uniform(2.51, a, b)
print(f"La probabilidad de que el tiempo esté entre 2.51 y 7.99 minutos es: {probabilidad_2_51_a_7_99}")
# Out:
# La probabilidad de que el tiempo esté entre 2.51 y 7.99 minutos es: 0.576842105263158
